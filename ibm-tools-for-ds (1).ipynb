# %% [markdown]
# {
#  "cells":
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# \"My Jupyter Notebook on IBM Watson Studio"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "**Seraia Pop**  \n",
#     "My desired occupation is a Chief Data Scientist or CIO!"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "*I am interested in data science because it allows you to manipulate and interpret data according to the needs of a company to find a successful solution and to prove a theorem.*"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### My code is supposed to add two numbers"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 11,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "x = 7
#       y = 18
#       print(x + y)"
#     }
#
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source":
#    [
#      " -  This is a bullteted list
#        -  It is one of the 3 necessities within cell 6
#        -  This is the end of the bulleted list"
#        " 1. This is a numbered list
#          2. This is the second necessity I have now completed from cell 6 requirements
#          3. This is the end of the numbered list "
#          ~~This is the final requirement for cell 6 - strikethrough~~
#
#    THANK YOU!
